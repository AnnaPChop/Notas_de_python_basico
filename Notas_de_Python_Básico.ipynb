# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaPChop/Notas_de_python_basico/blob/main/Notas_de_Python_B%C3%A1sico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variables en Python
#
# En los lenguajes de programación, las variables desempeñan la función de contenedores de otros valores (texto, números, etc.).
# ![1.2.3_ES_1696340266.png](data:image/png;base64,...![3.3ES_1707299526.png](data:image/png;base64,...))

# %%
message = "Hola Thuko"
print(message)
# Out:
# Hola Thuko

# %% [markdown]
# El uso de variables nos permite guardar esos valores para poder referirnos a ellos más adelante. Por ejemplo, ¿qué pasaría si quisiéramos trabajar con los 15 primeros dígitos de pi? Sería muy pesado tener que teclear ese número cada vez que deseáramos utilizarlo, por no mencionar que probablemente cometeríamos algún error aquí y allá. En su lugar, podemos crear una variable para almacenar ese número y, luego, utilizar el nombre de esa variable para usar el valor guardado en ella más adelante en nuestro código:

# %%
pi = 3.1416
print( pi +)
# Out:
# 4.1416

# %% [markdown]
# En Python, no podemos crear una variable sin asignarle un valor inicial. Todo lo que tenemos que hacer es escribir el nombre de la variable seguido del operador de asignación = y, a continuación, especificar el valor que queremos que almacene esa variable.
#
# # Sintaxis de una variable:
#
# La sintaxis se refiere a las reglas sobre cómo se escribe e interpreta el código. Si tu código no tiene la sintaxis adecuada, probablemente obtendrás un error cuando lo ejecutes. Python tiene las siguientes reglas sintácticas para nombrar variables:
#
# Los nombres de las variables solo pueden empezar por letras o por el carácter de subrayado _.
# Los nombres de las variables solo pueden contener letras, números y guiones bajos; otros caracteres especiales no están permitidos.
# Una cosa a tener en cuenta sobre los nombres de variables en Python es que distinguen entre mayúsculas y minúsculas. Así, por ejemplo, en Python una variable llamada My_Var y otra llamada my_var se considerarán variables diferentes.
#
# #Cómo funciona print():
#
# Puede que hayas notado que print() es un poco diferente de las variables que has visto: contiene paréntesis, mientras que los nombres de las variables no. Esto se debe a que print() es una función.
#
# Cuando llamamos a una función en nuestro código, los valores que introducimos entre los paréntesis se llaman argumentos. La función print() muestra en pantalla los valores de todos los argumentos que le pasamos.
#
# Importante: *Un número como argumento no requiere comillas*
# Importante 2: *Si colocamos varios print() seguidos, cada uno dara una respuesta*

# %%
message = "Thuko es lindo"

print(message)
print()
print(8)
# Out:
# Thuko es lindo
#
# 8

# %% [markdown]
# # Operaciones aritméticas:
#
# algunos de los operadores aritméticos básicos:
#
# Operador	Descripción	Ejemplo
# * \+	suma	3 + 5 = 8
# * \-	resta	6 - 3 = 3
# *	 \*multiplicación	3 * 2 = 6
# * \**	exponente	 3**2 = 9
# * /	división	5 / 2 = 2.5
# * //	división entera	5 // 2 = 2
# * %	módulo	14 % 3 = 2
#
# Estos operadores funcionan tal y como se esperaría si utilizaras una calculadora.
#
# # Orden de las operaciones:
# A menudo, necesitamos realizar cálculos que implican varios términos y una combinación de operadores aritméticos. La sintaxis de Python para ordenar las operaciones es la misma que la de PEMDAS: paréntesis, exponentes, multiplicación y división, suma y resta.

# %%
print( (2 ** 3 + 12 / 2) / (5 * 4 - 13) )
# Out:
# 2.0

# %% [markdown]
# #Cálculos con variables:
# Ahora ya sabemos lo básico de los cálculos aritméticos en Python. Pero el verdadero poder se encuentra en el uso de variables para almacenar nuestros resultados, que luego pueden usarse en cálculos posteriores.

# %%
Tortas_preparadas = 15
Tacos_preparados = 30
Pedidos = Tortas_preparadas + Tacos_preparados

print("Los pedidos realizados fueron", Pedidos)
# Out:
# Los pedidos realizados fueron 45

# %% [markdown]
# # Tipos de datos:
# Objetos y sus tipos
# Llamamos objeto a los datos almacenados en una variable, y cada objeto tiene un tipo de dato determinado.
#
# No tienes que indicar el tipo de dato cuando creas un objeto: Python lo hará por ti. Aún así, debes tener en cuenta los tipos de datos a la hora de escribir programas, en caso contrario, es probable que cometas errores involuntarios en tu código.
#
# Los tipos más comunes son números enteros, números de coma flotante, strings y valores booleanos (verdadero/falso). Los enteros y los flotantes son tipos de datos numéricos, mientras que las strings  son tipos de datos de texto.
#
# Importante: *Python tiene la función type() que se utiliza para determinar el tipo de dato.*

# %%
nombre = "Max"
edad = 28
altura = 166.3

print(type(nombre))
print(type(edad))
print(type(altura))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# # Suma en tipos de datos:
#
# Conclusiones en lo que respecta a la suma:
#
# * Al sumar strings, estas se concatenan, lo que básicamente significa que se unen en una sola cadena.
# * Al sumar números enteros, siempre resultará un número entero. Al sumar números flotantes, obtendremos un número flotante.
# * Al sumar un entero con un flotante, el resultado será un flotante. De hecho, cualquier operación aritmética con un flotante dará como resultado un flotante.
# * Al sumar booleanos, el resultado será un entero: True es igual a 1 y False es igual a 0. Así pues, cuando se suman booleanos, simplemente se cuentan todos los valores True.

# %% [markdown]
# #Conversión de tipos de datos:
#
# * **int() transforma un objeto en un tipo entero.**
# * **float() transforma un objeto en un tipo de coma flotante.**
# * **str() transforma un objeto en un tipo de cadena.**

# %%
puntuacion_final = 10.6
print(puntuacion_final)

puntuacion_final = int(10.6)
print(puntuacion_final)
# Out:
# 10.6
# 10

# %% [markdown]
# #Propiedades básicas de los strings:
# Comencemos con la creación de un objeto string en Python. Puedes hacerlo poniendo cualquier número de caracteres entre comillas, ya sean simples o dobles, y asignando todo esto a una variable.
#
# No importa si usamos comillas simples o dobles, ambos strings serán iguales. Incluso podemos usar esto a nuestro favor usando comillas dobles para los strings que tienen apóstrofos.
#
# Como puedes leer en el mensaje de error, nuestro primer string comienza con la primera comilla simple y termina con el apóstrofo de "Let’s", lo que hace que Python no pueda reconocer todo lo que viene después.
# Al cambiarlas a comillas dobles, Python entiende correctamente dónde comienza y dónde termina el string, interpretando el apóstrofo correctamente también.

# %%
my_string_1 = '¡String 1, string 2, string rojo, string azul!'
my_string_2 = "¡String 1, string 2, string rojo, string azul!"

print(my_string_1)
print(my_string_2)

print("Let's learn about strings")
# Out:
# ¡String 1, string 2, string rojo, string azul!
# ¡String 1, string 2, string rojo, string azul!
# Let's learn about strings

# %% [markdown]
# #Caracteres de escape:
# Quizás te estés preguntando: “¿Qué pasa si quiero crear un string que contenga comillas simples y dobles?” Python tiene una forma de permitirnos hacer precisamente eso (y más) usando caracteres de escape en nuestros strings.
#
# Los caracteres de escape se designan con una barra invertida seguida de cualquier carácter especial que queramos en nuestro string. Esto nos ofrece una forma de mostrar el string del ejercicio anterior sin usar comillas dobles.
#
# En este caso, el carácter de escape es \'. Observa en la salida que Python no incluye \ en el propio string: simplemente está ahí para que Python sepa que queremos que nuestro string incluya el carácter '. Del mismo modo, podemos utilizar \" para incluir el carácter " en un string que está entre comillas dobles.
#
# Además de las comillas simples y dobles, hay varios otros caracteres de escape. La mayoría de ellos se utilizan para formatear texto, siendo los dos más comunes:
#
# * \n: el carácter de nueva línea, para agregar un salto de línea, haciendo que tu string continúe en la siguiente línea.
# * \t: el carácter de tabulación, para agregar tabulación a tu string.

# %%
print('Let\'s learn about strings!')
# Out:
# Let's learn about strings!

# %% [markdown]
# #Strings de varias líneas:
# A las computadoras les da igual la longitud de una línea de texto, pero a las personas les resulta mucho más fácil leer el texto cuando cada nueva idea comienza en una nueva línea.
#
# Aunque este string del ejercicio anterior se muestra muy bien cuando lo pasamos a la función print(), sería una molestia para cualquiera que lea nuestro código encontrarle sentido (¡especialmente si nuestra lista de compras es larga!).
#
# ¡Afortunadamente, Python nos permite crear strings de varias líneas! Para hacerlo, envuelve el string en tres comillas simples ’’’ o dobles ”””. Aquí tienes un ejemplo:

# %%
shopping_list = """Mi lista de compras:
2 cartones de leche,
cereales de desayuno,
huevos,
pan"""

print(shopping_list)
# Out:
# Mi lista de compras:
# 2 cartones de leche,
# cereales de desayuno,
# huevos,
# pan

# %% [markdown]
# #Longitud del string:
# A menudo, necesitamos saber la longitud de un string como parte de nuestro trabajo de procesamiento y análisis de datos. La longitud de un string es igual a la cantidad de caracteres que tiene. Los strings pueden tener cualquier longitud, siendo la única limitación la memoria de la computadora.
#
# Python tiene una función llamada len() que podemos usar para calcular fácilmente la longitud de cualquier string.
#
# Importante: *Es importante tener en cuenta que los caracteres de escape y los espacios también cuentan como un carácter para la longitud del string.*
#
# Aquí está len() en acción:

# %%
cancion = ''' Voy por la ruta en mi camioneta blanca
Está un poco vieja, pero todavía arranca
Y subo la radio a un volumen intenso
A veces prefiero no escuchar lo que pienso
Y un tipo hablando con lenguaje complicado
Dice que sólo queremos estar ocupados
Para no ver la realidad, y la vida tal cual es
Y que hay que terminar con tanta estupidez '''

print(cancion)
print()
print(len(cancion))
# Out:
#  Voy por la ruta en mi camioneta blanca
# Está un poco vieja, pero todavía arranca
# Y subo la radio a un volumen intenso
# A veces prefiero no escuchar lo que pienso
# Y un tipo hablando con lenguaje complicado
# Dice que sólo queremos estar ocupados
# Para no ver la realidad, y la vida tal cual es
# Y que hay que terminar con tanta estupidez
#
# 332

# %% [markdown]
# #Índices:
# En Python, los strings se pueden considerar como una secuencia de caracteres en la que a cada carácter se le asigna un índice desde cero (al principio) hasta la longitud menos uno (al final).
#
# Un índice no es más que un número que identifica la posición de dicho carácter en el string, y sí, puede sonar extraño, pero el primer carácter tiene el índice 0 en lugar de 1. Este es un comportamiento que puedes encontrar en muchos otros lenguajes de programación.
#
#
# ## Acceso a los caracteres de un string:
# Puedes acceder a cualquier carácter determinado haciendo referencia a su índice. Todo lo que tienes que hacer es colocar el índice entre corchetes después de la variable que contiene el string. Pero presta atención: como muestra la imagen de arriba, la indexación comienza desde cero.

# %%
message = "Thukito es muy lindo"
print(message[5])
# Out:
# t

# %% [markdown]
# #Indexación negativa:
# Python también nos brinda una forma práctica de indexar comenzando desde el final del string. Esto se llama indexación negativa y se hace utilizando números negativos como índice. El último carácter del string asume -1 como índice, el anterior tiene -2 como índice, y así sucesivamente hasta llegar al primer carácter del string. Ejecuta el siguiente código para ver cómo funciona la indexación negativa.

# %%
message = "Thukito es hermoso"
print(message[-3])
# Out:
# o

# %% [markdown]
# #Slices:
# El slicing te permite seleccionar varios caracteres de un string en lugar de solo uno, para que puedas acceder a tus datos más rápido y trabajar de manera más eficiente.
#
# Al final de esta lección, podrás usar slices para acceder a cualquier subconjunto de caracteres de un string.
#
# Para dividir un string, usamos la indexación, pero hay un poco más de lo que aprendimos en la última lección. Para los slices, necesitamos colocar los índices inicial y final dentro de los corchetes, separados por dos puntos.
#
# Es importante recalcar que  el último carácter del rango no forma parte del resultado final. Por lo tanto, el número de caracteres en un substring siempre será igual al índice final menos el índice inicial. Conocer esta propiedad del slicing en Python te ayudará a asegurarte de que tu código te proporcione los slices que esperas.

# %%
message = "Solo fue Thukito a comprar hielo"
print(message[9:16])
print(message[-23:-16])
# Out:
# Thukito
# Thukito

# %% [markdown]
# #Strings formateados:
# Cuando tu código es significativamente largo, esta práctica ha de conducir casi inevitablemente a errores, por lo que es mucho mejor usar variables en su lugar.
#
# Podemos hacer esto dividiendo el string anterior en strings separados y concatenándolos con nuestras variables en el lugar donde queremos que se muestren. Para hacerlo, usamos el signo +, como hemos visto antes.

# %%
persona = "Thukito"
cantidad = 8
lugar_de_compra = "Oxxo"

message = persona + " fue al " + lugar_de_compra + " a comprar " + str(cantidad) + " pepsi kicks."

print(message)
# Out:
# Thukito fue al Oxxo a comprar 8 pepsi kicks.

# %% [markdown]
# #F-strings:
# Crear f-strings es bastante sencillo: todo lo que tenemos que hacer es anteponer nuestro string con la letra f (piensa en la F de "formateado") antes de las comillas de apertura. Los nombres de las variables dentro del f-string se indican entre llaves {}.

# %%
persona = "Thukito"
cantidad = 8
lugar_de_compra = "Oxxo"

message = f" {persona} fue al {lugar_de_compra} a comprar {cantidad} pepsi kicks."
print(message)
# Out:
#  Thukito fue al Oxxo a comprar 8 pepsi kicks.

# %% [markdown]
# #El método format():
#
# También podemos usar el método de string format() para obtener los mismos resultados que acabamos de obtener usando f-strings. Los métodos son como funciones especiales a las que podemos llamar en objetos individuales. Aprenderemos más sobre los métodos de string más adelante en este capítulo.
#
# Por ahora, te mostraremos cómo usar format():

# %%
persona = "Thukito"
cantidad = 8
lugar_de_compra = "Oxxo"

message = "{} fue al {} a comprar {} pepsi kicks.".format(persona,lugar_de_compra,cantidad)
print(message)
# Out:
# Thukito fue al Oxxo a comprar 8 pepsi kicks.

# %% [markdown]
# #Métodos de string:
# En la lección anterior, aprendiste sobre el método específico de string format() y cómo podemos llamarlo en objetos string para resolver el problema de incorporar variables en nuestros strings. Resulta que los strings tienen una plétora de métodos, cada uno de los cuales está diseñado para procesar strings de una manera diferente.
#
# El uso de métodos de string para procesar strings es una parte fundamental del análisis y el modelado de datos de texto. Al final de esta lección, podrás utilizar los siguientes métodos como parte de tu código:
#
# * upper() convierte todos los caracteres a mayúsculas;
# * lower() convierte todos los caracteres a minúsculas;
# * replace() reemplaza partes de un string por otro string;
# * strip() elimina los espacios al principio y al final del string.
#
# ##Normalizar mayúsculas y minúsculas:
#
# Durante las fases de limpieza y procesamiento de datos de nuestro trabajo, a menudo necesitamos considerar el uso de mayúsculas en nuestros datos de texto porque los strings distinguen entre mayúsculas y minúsculas en Python. En otras palabras, Python trata los strings 'Hola', 'hola' y 'HOLA' como valores distintos.
#
# Podemos evitarlo normalizando las mayúsculas de nuestros strings, lo que significa hacer que todas las letras sean mayúsculas o minúsculas. De esa forma, es mucho más fácil encontrar valores duplicados o agrupar datos de texto por categorías únicas.
#
# Tenemos dos métodos para lograr esto: upper() y lower(). El método upper() convierte todas las letras a mayúsculas y el método lower() convierte todas las letras a minúsculas.

# %% [markdown]
# #Reemplazar un substring:
#
# Otra parte común del procesamiento de datos de texto es eliminar o reemplazar partes de strings. Por ejemplo, tal vez necesitemos corregir errores tipográficos en los números de teléfono de los clientes y las clientas o eliminar los nombres de dominio de las direcciones de correo electrónico. Como sabes, los objetos de string son inmutables, por lo que si quisiéramos hacer algunos cambios, tendríamos que reasignar todo el string. Afortunadamente, podemos usar el método replace() para eliminar o reemplazar substrings (partes de strings).
#
# El método replace() toma dos argumentos:
#
# el substring que queremos reemplazar;
# el string por el que queremos reemplazarlo.

# %%
message = ''' Mis pizzas favoritas son:
Pizza con peperoni
Pziza con piña
Pizza con champiñones '''
print(message.replace("Pziza","Pizza"))
# Out:
#  Mis pizzas favoritas son:
# Pizza con peperoni
# Pizza con piña
# Pizza con champiñones

# %% [markdown]
# #Eliminar espacios en blanco:
#
# Por último, otro procedimiento común en el procesamiento de datos de texto es eliminar los espacios en blanco al principio y al final de un string.
#
# Por ejemplo, a veces, cuando se exportan datos entre sistemas, se pueden introducir anomalías como espacios iniciales en los nombres de columna. Esto puede dificultar la escritura y el intercambio de código que utiliza los mismos datos.
#
# El método strip() elimina todos los espacios en blanco al principio y al final de un string; se conservan todos los espacios en blanco dentro del resto del string. Por espacios en blanco, nos referimos a caracteres como espacios, tabulaciones y saltos de línea.

# %%
column_name = '     fecha de compra  '

print(column_name)
print(len(column_name))
print()
print(column_name.strip())
print(len(column_name.strip()))
# Out:
#      fecha de compra
# 22
#
# fecha de compra
# 15

# %% [markdown]
# #Propiedades básicas de las listas:
# Hasta ahora, trabajábamos con tipos de datos de Python que tenían valores individuales. Las listas son diferentes: nos permiten almacenar una colección de valores dentro de una única estructura de datos. Esto es útil cuando tenemos toneladas de datos. Si tuviéramos una tabla con miles de valores, sería un dolor de cabeza tener que almacenar cada uno de esos valores en su propia variable. En su lugar, podemos almacenarlos todos en una lista, y luego elegir con qué valores trabajar según sea necesario.
#
# ##Crear una lista:
#
# Las listas se crean utilizando corchetes. Podemos crear una lista vacía poniendo los corchetes sin ningún valor dentro:

# %%
my_list = []

print(my_list)
print(type(my_list))
print(len(my_list))
# Out:
# []
# <class 'list'>
# 0

# %% [markdown]
# #Índices y slices:
# ##Indexación de listas:
# Al igual que una cadena, una lista es una colección ordenada de elementos. Eso significa que cada elemento tiene una determinada "posición en la fila", es decir, un índice. La indexación de listas comienza en 0 y se incrementa en 1 por cada elemento subsiguiente.
#
# ##Acceder a un elemento:
# Para acceder a un elemento en un índice determinado, hay que poner el número de índice entre corchetes después de la lista (al igual que lo hicimos con las cadenas):

# %%
movie_info = ['Fight Club', 1999, ['thriller', 'drama', 'crime'], 139, 8.644]

print(movie_info[0])
print(type(movie_info[0]))
# Out:
# Fight Club
# <class 'str'>

# %% [markdown]
# #Slicing en listas:
# Acceder a un elemento concreto de una lista es algo que haremos con mucha frecuencia. ¿Pero qué pasa si queremos acceder a más de uno? Slicing es la forma de indexar listas para obtener varios elementos a la vez.
#
# La sintaxis general que se usa al segmentar una lista es poner el primer y último valor de índice del slice después de la lista, separándolos con dos puntos y colocándolos entre corchetes.
#
# **Importante**: Aspectos a tener en cuenta:
#
# El elemento con índice superior no está incluido en la lista.
# El tipo de datos de un slice de lista también es una lista.
# La longitud de un slice es igual a la diferencia entre los índices superior e inferior.
# La buena noticia es que, a diferencia de los elementos individuales, al trabajar con los slices podemos incluir el índice superior que está fuera del intervalo de índices y, aun así, no obtendremos ningún error. En su lugar, obtendremos todos los elementos, incluido hasta el último elemento de la lista.

# %%
movie_info = ['Fight Club', 1999, ['thriller', 'drama', 'crime'], 139, 8.644]

print(movie_info[1:4])
print(type(movie_info[1:4]))
print(len(movie_info[1:4]))
# Out:
# [1999, ['thriller', 'drama', 'crime'], 139]
# <class 'list'>
# 3

# %% [markdown]
# #Modificación de listas (Append(), Extend(), Insert() y Pop()) :
# ##Modificar listas:
# Podemos ver que las cadenas y las listas tienen muchas cosas en común, pero hay una diferencia significativa: las listas pueden modificarse. En términos de Python, las listas son objetos mutables, mientras que las cadenas son inmutables, es decir, sus valores no se pueden actualizar.
#
# Al final de esta lección serás capaz de modificar listas empleando los métodos append(), extend(),  insert() y pop(). Estos métodos nos ofrecen una forma sencilla de añadir o eliminar información de una lista existente. Y es mucho más fácil cambiar elementos dentro de una lista que volver a crearla desde cero cada vez que quieras modificarla.
#
# Añadir elementos a una lista
# Existen tres modos de añadir elementos a una lista:
#
# * Añadiendo un elemento al final de la lista;
# * Añadiendo varios elementos al final de la lista;
# * Añadiendo un elemento en un índice determinado.
#
# Veamos cómo funciona cada uno de ellos.
#
# ##Añadir un elemento al final de una lista:
# Una forma sencilla de añadir un elemento a una lista es llamar al método append().
#
# Hay que llamar a append() en una lista y pasarle el elemento que queramos agregar como argumento. Entonces append() añade ese elemento al final de la lista, incrementando su longitud en 1.
#
# **Importante**: Ten en cuenta que append() modifica la lista sobre la que fue llamado; no devuelve un nuevo objeto de lista.
#
# ##Añadir múltiples elementos al final de una lista:
# Con append() solamente podemos añadir un elemento. Para añadir varios, necesitamos llamar al método extend().
#
# Este método se llama sobre una lista, a la que pasamos otra lista cuyos elementos queremos añadir como argumento. Al igual que append(), extend() modifica la lista original en lugar de devolver una nueva.
#
# ##Añadir un elemento en un índice específico:
# El método append() tiene dos limitaciones:
#
# * Añade solamente un elemento.
# * Añade el elemento únicamente al final de la lista.
# * El método extend() elimina la primera limitación. ¿Pero qué pasa con la segunda?
#
# Para agregar un elemento en la posición que quieras, necesitas llamar al método insert(). Este método toma dos argumentos: el índice en el que se insertará un nuevo elemento y el valor del mismo.
#
# ##Eliminar un elemento:
# Saber cómo se añaden elementos a una lista es solo una parte del trabajo. A veces, necesitamos hacer lo contrario: eliminar un elemento de una lista. Para ello se puede utilizar el método pop().
#
# Cuando se aplica sin argumentos, este método elimina un elemento del final de la lista.
#
#
# ###Recapitulemos brevemente lo que sabemos hasta ahora sobre la modificación de listas:
#
# * append() se puede usar para agregar un solo elemento al final de una lista.
# * extend() se usa para agregar múltiples elementos al final de una lista.
# * insert() se necesita para insertar un elemento en cualquier parte de una lista.
# * pop() permite eliminar cualquier elemento de una lista.

# %%
movies = ['Matrix', 'Matrix 2', 'Matrix 3']
movies.pop(1)
print(movies)
# Out:
# ['Matrix', 'Matrix 3']

# %%
dark_knight_movie = ['The Dark Knight', 'USA', 'fantasy, action, thriller', 152]
dark_knight_movie.insert(2, 2008)
print(dark_knight_movie)
# Out:
# ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152]

# %%
godfather_movie = ['The Godfather', 'USA', 1972]
godfather_movie.extend(['Francis Ford Coppola', 'Nino Rota'])
print(godfather_movie)
# Out:
# ['The Godfather', 'USA', 1972, 'Francis Ford Coppola', 'Nino Rota']

# %%
shawshank_movie = ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111]
shawshank_movie.append('Frank Darabont')
print(shawshank_movie)
# Out:
# ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111, 'Frank Darabont']

# %% [markdown]
# #Ordenar listas (Sort()):
# Al igual que una cadena, una lista es una colección ordenada de elementos. Pero a diferencia de los strings, podemos cambiar el orden de los elementos de una lista debido a que estas son objetos mutables.
#
# Al final de esta lección, serás capaz de utilizar tanto el método sort() como la función incorporada sorted() de Python para reordenar los elementos de una lista. Además, podrás explicar las diferencias entre estas dos técnicas. La ordenación es una herramienta útil para organizar alfabéticamente los datos de cadenas, comprender el rango de datos numéricos y mucho más.
#
# El método sort()
# Tomemos como ejemplo una lista con los años de estreno de diferentes películas y mostremos esta lista antes y después de ordenarla con el método sort()
#
# *Dos cosas a tener en cuenta sobre nuestro futuro resultado:*
#
# El método sort() modifica la lista original en lugar de crear una nueva.
# Por defecto, este método ordena los elementos en orden ascendente, de menor a mayor.
# Si queremos ordenar por orden descendente, debemos pasar al método el parámetro reverse= y asignarle el valor True.
#
# ##A continuación, se detalla la prioridad de la ordenación lexicográfica en orden ascendente:
#
# * Signos de puntuación
# * Números
# * A-Z
# * a-z

# %%
years = [1994, 1972, 2008, 1993, 2003, 1994, 1966, 1999, 1962, 1997]
print(years)

years.sort()
print(years)
# Out:
# [1994, 1972, 2008, 1993, 2003, 1994, 1966, 1999, 1962, 1997]
# [1962, 1966, 1972, 1993, 1994, 1994, 1997, 1999, 2003, 2008]

# %%
years = [1994, 1972, 2008, 1993, 2003, 1994, 1966, 1999, 1962, 1997]

years.sort(reverse=True)
print(years)
# Out:
# [2008, 2003, 1999, 1997, 1994, 1994, 1993, 1972, 1966, 1962]

# %% [markdown]
# ##Uso de la función sorted()
# Como ocurre a menudo en programación, hay más de una forma de realizar una tarea determinada. Python tiene una función incorporada llamada sorted() que también puede usarse para ordenar listas y otros tipos de datos. Se diferencia de sort() en dos aspectos importantes:
#
# sort() es un método de lista que solo puede llamarse sobre objetos de lista, mientras que sorted() es una función.
# El método sort() modifica la lista, mientras que la función sorted() genera una nueva lista ordenada.
# Para ilustrar lo dicho anteriormente, comparemos los resultados de ambos enfoques. Empecemos ordenando la lista mediante la función sorted():

# %%
years = [1994, 1972, 2008, 1993, 2003, 1994, 1966, 1999, 1962, 1997]

years_sorted = sorted(years)

print(years_sorted)
# Out:
# [1962, 1966, 1972, 1993, 1994, 1994, 1997, 1999, 2003, 2008]

# %% [markdown]
# #Listas anidadas:
# Las listas anidadas son, básicamente, listas dentro de listas donde el primer nivel de anidación corresponde a la lista principal, cuyos elementos son listas independientes (sublistas). Los elementos de estas sublistas son objetos más simples, como números o cadenas.
# Gracias a estas estructuras, puedes crear, almacenar y mostrar información organizada en Python, por ejemplo, tablas. El hecho de almacenar información en forma de tabla puede facilitar y acelerar el análisis, así como mejorar los procesos de toma de decisiones. Como especialista en datos, te encontrarás con tablas muy a menudo.
#
# ##Recuperación de datos de una lista anidada:
# Cuando una tabla se representa como un listado de listas, el primer índice indica una fila (o sea, una sublista concreta) y el segundo una columna (es decir, un índice concreto de una sublista). Podemos utilizar estas dos coordenadas para acceder a cualquier elemento individual.

# %%
movies_info = [
    ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111],
    ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.730],
    ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499],
    ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818],
    ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625],
    ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619],
    ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521],
    ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644],
    ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106],
    ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
]

print(movies_info[-1][1])
print(movies_info[5][2])
print(movies_info[1][-1])
# Out:
# USA
# 1994
# 8.73

# %% [markdown]
# #Procesamiento de cadenas (Split() y Join()):
# Las listas disponen de algunos métodos únicos incorporados que sirven de gran ayuda a la hora de procesar cadenas, por lo que los analistas y las analistas de datos suelen transformar cadenas en listas para realizar cálculos y procesar texto. Este enfoque es muy útil cuando queremos modificar textos (por ejemplo, eliminar palabras repetidas o sustituir determinados fragmentos).
#
# Al convertir tu cadena en una lista de elementos, puedes beneficiarte de potentes técnicas y métodos de listas para procesar y analizar datos de texto y, a continuación, volver a convertir la lista en una cadena con el fin de imprimirla o analizarla posteriormente.
#
# En esta lección, conocerás el método split() que convierte una cadena en una lista. Asimismo, introduciremos el método join() que permite convertir una lista en una cadena.
#
# ##Dividir una cadena en una lista:
# Por defecto, split() divide una cadena allí donde haya espacios. Los caracteres comprendidos entre los espacios se convierten en los elementos de la lista
#
# ##Combinar elementos de una lista en una cadena:
# Muchas veces dividimos cadenas para poder modificarlas. Más adelante en este curso, descubrirás todas las operaciones que se pueden realizar. Por ahora, supongamos que hemos hecho los cambios necesarios. Una vez realizados todos los cambios oportunos, podemos volver a convertir la lista en una cadena utilizando el método join().
#
# El método join() espera una lista como entrada y requiere un objeto sobre el que llamarse. Este objeto es una cadena que se insertará entre cada elemento de la lista. Normalmente, dividimos una cadena en palabras mediante espacios, por lo que es habitual utilizar ' ' como objeto.

# %%
phrase = 'Esta-noche-no-se-ven-las-estrellas'
words = phrase.split('-')
print(words)
# Out:
# ['Esta', 'noche', 'no', 'se', 'ven', 'las', 'estrellas']

# %%
words = ['Mi', 'película', 'favorita', 'es', 'The', 'Graduate.']
phrase = ' '.join(words) # forma una cadena a partir de los elementos, separados por espacios
print(phrase)
# Out:
# Mi película favorita es The Graduate.

# %% [markdown]
# #Operadores de asignación aumentada y funciones integradas (Min(), Max() y Sum()):
# Antes de profundizar en los bucles, nos gustaría presentar dos conceptos que se usan con frecuencia junto con los bucles para simplificar y optimizar el código: la asignación aumentada y las funciones integradas como min(), max() y sum().
#
# Mediante el uso de la asignación aumentada, puedes actualizar fácilmente el valor de una variable sin tener que duplicar su nombre, mientras que las funciones integradas brindan soluciones preparadas para realizar cálculos y operaciones comunes. Comprender estos conceptos te ayudará a escribir un código de Python más eficiente y eficaz.
#
# ##Asignación aumentada:
# Por supuesto, incluso con el método anterior, aún estás duplicando el nombre de la variable y haciendo posible que ocurra un error humano. Solo un error tipográfico y fr_speakers puede convertirse en fi_speakers, ¡y te resultará difícil averiguar por qué desaparecieron todos esos hablantes de francés! ¡Tal vez fue el invierno finlandés y no un error tipográfico!
#
# Para ayudarte a evitar esos errores, existe un método más corto y útil llamado asignación aumentada.
#
# **En resumen**:
#
# La función sum() toma una lista como argumento y devuelve la suma de sus elementos.
# La función max() se usa para encontrar el valor máximo.
# La función min() se usa para encontrar el valor mínimo de la lista.

# %%
movies_duration = [142, 175, 152, 195, 201, 154, 178, 139, 133, 126]

total_duration = sum(movies_duration) #suma todos los elementos de la lista
max_duration = max(movies_duration) #obtiene el elemento más grande en la lista
min_duration = min(movies_duration) #obtiene el elemento más pequeño en la lista


print(total_duration)
print(max_duration)
print(min_duration)
# Out:
# 1595
# 201
# 126

# %%
items = 10

items += 5 # igual que items = items + 5
print(items)

items -= 5 # igual que items = items - 5
print(items)

items *= 3 # igual que items = items * 3
print(items)

items /= 5 # igual que items = items / 5
print(items)
# Out:
# 15
# 10
# 30
# 6.0

# %% [markdown]
# #Bucles for:
# El tipo de bucle más común en Python es el bucle for, que comienza con la palabra clave for. Recorre los elementos en una secuencia y realiza operaciones similares en cada uno de ellos. La secuencia que usamos puede ser cualquier objeto ordenado, como listas o strings.
#
# ##Componentes del bucle:
# * La palabra clave for.
# * Nuestra variable de bucle element. En cada iteración del bucle toma el valor de un elemento de la secuencia y te permite realizar algunas operaciones en él. * Puedes usar cualquier nombre para esta variable, pero es mejor asegurarse de utilizar uno que sea claro y significativo.
# * La palabra clave in.
# * La lista your_list. El nombre de la lista que está siendo procesada por el bucle.
# * Los dos puntos : son un elemento esencial que separa las dos partes del bucle.
# * La función print(element). Esto constituye el cuerpo del bucle. El cuerpo contiene comandos que el bucle ejecuta en cada iteración del bucle. Cada comando en el cuerpo del bucle está precedido por una indentación de cuatro espacios, lo que indica que el comando debe ejecutarse dentro del bucle, separado del resto del código.

# %%
message_japanese = '機械翻訳は通常良くありません'
for kanji in message_japanese:
     print(kanji)
# Out:
# 機
# 械
# 翻
# 訳
# は
# 通
# 常
# 良
# く
# あ
# り
# ま
# せ
# ん

# %% [markdown]
# #Bucles sobre listas anidadas:
# En cada iteración, el bucle almacena un elemento de la lista en la variable row. Ese elemento es otra lista, pero no tienes que preocuparte por eso. La función print() en el cuerpo del bucle muestra los elementos de la lista uno por uno hasta mostrar la lista completa

# %%
movies_info = [
    ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111],
    ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.730],
    ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499],
    ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818],
    ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625],
    ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619],
    ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521],
    ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644],
    ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106],
    ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
]

for row in movies_info:
    print(row)
# Out:
# ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111]
# ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.73]
# ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499]
# ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818]
# ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625]
# ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619]
# ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521]
# ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644]
# ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106]
# ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]

# %% [markdown]
# #Bucles while:
# Hay varios tipos de bucles, incluidos los bucles for y while. Cada tipo es útil para resolver diferentes problemas. Como hemos visto, los bucles  for son excelentes cuando sabes de antemano que necesitarás ejecutar un conjunto de instrucciones una determinada cantidad de veces, como la cantidad de elementos en una lista.
#
# Pero cuando no sabemos cuántas veces tendremos que repetir un fragmento de código, los bucles while vienen a ayudar. Por ejemplo, esto puede resultar de gran utilidad:
#
# Cuando un usuario rellena un formulario, podría haber un bucle que procese datos al tiempo que se van introduciendo. El bucle sigue iterando hasta que todos los datos se hayan ingresado correctamente.
# Si una cámara web reacciona al movimiento, un bucle puede transmitir datos hasta que el movimiento se detenga.
# En los bucles while, la condición se comprueba antes de cada iteración. Si esta condición es True, el algoritmo ejecuta las instrucciones dentro del cuerpo del bucle. Una vez que la expresión lógica en la condición devuelva False, el bucle se detendrá.
#
# Veamos otro ejemplo. Un ascensor inteligente puede medir el peso total de las personas en su interior y compararlo con la capacidad del ascensor. Cada vez que una nueva persona entra en el ascensor, el bucle while comprueba si se ha alcanzado el peso máximo.
#
# En este experimento, supondremos que el peso en kilogramos de cada nueva persona es un valor aleatorio de 30 a 120. Los valores aleatorios pueden asignarse a las variables usando la función randint() de la librería random. La función randint genera números enteros aleatorios dentro de un rango específico, por consiguiente declararemos el rango de 30 a 120 y simularemos el peso de una persona al azar. Hablaremos de la generación de números aleatorios y las librerías con más detalle más adelante. Por ahora, supongamos que podemos importar randint() desde la caja de herramientas random y usarla como herramienta para nuestras necesidades.

# %%
# Los valores aleatorios pueden ser asignados a las variables utilizando la función randint() de la librería al azar
# La función randint genera números enteros aleatorios dentro de un rango específico,
# por consiguiente declararemos el rango de 30 a 120 y simularemos el peso de una persona al azar.

from random import randint # importamos la función randint de la librería random

capacity = 400 # capacidad del ascensor en kg
total_weight = 0 # variable que almacena el peso total

while total_weight < capacity: # mientras que el peso total es menor que la capacidad máxima
    person_weight = randint(30, 120) # generamos un número aleatorio de 30 a 120
    total_weight += person_weight # el peso generado se añade a la impresión del peso total
    print(f'Entra una persona. Carga del ascensor: {total_weight}')

print('¡Lo sentimos! El ascensor está lleno. Tendrás que esperar al siguiente.')
# Out:
# Entra una persona. Carga del ascensor: 103
# Entra una persona. Carga del ascensor: 143
# Entra una persona. Carga del ascensor: 197
# Entra una persona. Carga del ascensor: 313
# Entra una persona. Carga del ascensor: 414
# ¡Lo sentimos! El ascensor está lleno. Tendrás que esperar al siguiente.

# %% [markdown]
# Antes de cada paso, el bucle comprueba la variable total_weight. Si está por debajo del límite de capacity, el bucle ejecutará las instrucciones de su cuerpo. Luego volverá a la primera línea y comprobará de nuevo si el peso total es menor que la capacidad máxima. Cuando se haya alcanzado o excedido el límite, el bucle se detendrá y se mostrará el texto que se encuentra fuera del cuerpo del bucle.
#
# El signo < en el bucle while es un operador de comparación que comprueba si el valor de la derecha es mayor que el valor de la izquierda, al igual que el operador matemático. En el contexto de un bucle while, se utiliza para comprobar si una determinada condición es True (verdadera) o False (falsa). Si la condición es verdadera, se ejecutará el código dentro del bucle. Hablaremos más sobre estos operadores de comparación en el próximo capítulo.
#
# No sabemos cuántos pasos ejecutará el bucle. Eso depende de cuán rápido el peso total alcance el límite, pero cuando lo haga, el bucle finalizará.

# %% [markdown]
# #Uso de contadores:
# while se puede utilizar con una variable de contador, que puede usarse para detener el bucle, o puedes usar contadores simplemente para saber cuántas veces se repitió el bucle.
#
# Veamos de nuevo el ejemplo del ascensor, pero esta vez queremos evitar que más de 10 personas entren en el ascensor.

# %%
num_people = 0 # comienza en 0 y no hay nadie dentro
capacity = 10 # variable que almacena el límite de personas

while num_people < capacity: # mientras que el número de personas es menor que la capacidad máxima
    num_people += 1 # una persona entra
    print(f'Entra una persona. Carga del ascensor: {num_people}')

print('¡Lo sentimos! El ascensor está lleno. Tendrás que esperar al siguiente.')
# Out:
# Entra una persona. Carga del ascensor: 1
# Entra una persona. Carga del ascensor: 2
# Entra una persona. Carga del ascensor: 3
# Entra una persona. Carga del ascensor: 4
# Entra una persona. Carga del ascensor: 5
# Entra una persona. Carga del ascensor: 6
# Entra una persona. Carga del ascensor: 7
# Entra una persona. Carga del ascensor: 8
# Entra una persona. Carga del ascensor: 9
# Entra una persona. Carga del ascensor: 10
# ¡Lo sentimos! El ascensor está lleno. Tendrás que esperar al siguiente.

# %% [markdown]
# Puedes ver que en cada iteración el código muestra la cantidad de personas en el ascensor. El último número mostrado es 10. Después de eso, no se imprimen números, lo que significa que el bucle finalizó.
#
# Luego, vamos a ver cómo podemos determinar la cantidad de personas necesaria para que el ascensor alcance su carga máxima. ¡Ejecútalo varias veces y verás la función randint() en acción!

# %%
from random import randint

capacity = 400 # capacidad del ascensor en kg
total_weight = 0 # variable que almacena el peso total
num_people= 0 # comienza en 0, no hay nadie dentro

while total_weight < capacity: # mientras que el peso total es menor que la capacidad máxima
    person_weight = randint(30, 120) # generamos un número aleatorio de 30 a 120
    total_weight += person_weight # el peso generado se agrega al peso total
    num_people += 1 # una persona entra
    print(f'Entra una persona. Carga del ascensor: {total_weight}')

print(f'¡Lo sentimos! El ascensor está lleno. Tendrás que esperar al siguiente. \nHay {num_people} personas dentro')
# Out:
# Entra una persona. Carga del ascensor: 102
# Entra una persona. Carga del ascensor: 142
# Entra una persona. Carga del ascensor: 243
# Entra una persona. Carga del ascensor: 355
# Entra una persona. Carga del ascensor: 418
# ¡Lo sentimos! El ascensor está lleno. Tendrás que esperar al siguiente.
# Hay 5 personas dentro

# %% [markdown]
# #Bucles infinitos:
# Ten en cuenta que el uso de bucles while tiene un problema: si la comparación en el encabezado nunca devuelve False, se produce un bucle infinito. Luego el cuerpo del bucle sigue ejecutándose.

# %%
ales = 1000 # establecemos el valor de sales en 1000

while sales > 100: # siempre que el valor en sales sea superior a 100,
    sales += 1 # incrementamos el valor de sales en 1
    print(sales) # y lo imprimimos

# %% [markdown]
# #Expresiones lógicas y operadores de comparación:
# Hasta ahora has estado creando programas simples, en los que las líneas de código simplemente se ejecutan una tras otra; sin embargo, a veces debemos agregar flexibilidad al comportamiento del programa. Podemos hacer esto mediante sentencias condicionales.
#
# Digamos que es otoño. Estás tratando de averiguar si necesitas llevar un paraguas para salir de casa.
#
# Si está lloviendo, llevarás un paraguas; si no está lloviendo, llevarás un sombrero.
#
# El resultado de comprobar la condición (¿está lloviendo?) determina qué rama del algoritmo se ejecutará (con paraguas o sin paraguas).
#
# La estructura básica de cualquier sentencia condicional es: IF <statement is True>, THEN <do this> (SI <la sentencia es True>, ENTONCES <haz esto>).
#
# Para definir la primera parte de la sentencia condicional utilizamos expresiones lógicas.

# %% [markdown]
# #Expresiones lógicas:
# Hay varios tipos de expresiones en Python que devuelven True o False:
#
# * Expresiones que contienen operadores de comparación: ==, !=, >, <, >=, <=.
# * Expresiones que contienen operadores lógicos: and, or, not.
# * Funciones de predicado.
# * Operadores de comparación
#
# **Importante**: Al usar operadores de comparación, es importante saber que no podemos comparar tipos de datos completamente diferentes.
#
# Cuando usamos operadores de comparación, podemos comparar float con int. De hecho, Python puede convertir int en float de forma automática cuando sea necesario, pero no puedes comparar tipos de datos completamente diferentes. Por ejemplo, no puedes comparar números con cadenas.

# %% [markdown]
# #Operadores lógicos (And, or y not):
# Los operadores lógicos son herramientas increíblemente útiles en programación, ya que permiten combinar y evaluar múltiples condiciones en una expresión lógica. En Python existen tres operadores lógicos de uso común ("and", "or" y "not") que se pueden utilizar para crear sentencias condicionales más complejas que pueden manejar múltiples condiciones.
#
# * El operador "and" se utiliza para comprobar si las dos condiciones en una sentencia son verdaderas. Si las dos condiciones son verdaderas, la sentencia completa también es verdadera; por el contrario, si una o ambas condiciones son falsas, entonces la sentencia completa es falsa.
#
# * El operador "or", por otro lado, comprueba si una o ambas condiciones en una sentencia son verdaderas. Si al menos una de las condiciones es verdadera, entonces la sentencia completa es verdadera. La sentencia solo será falsa si las dos condiciones son falsas.
#
# * inalmente, el operador "not" es un operador unario que se utiliza para revertir el valor verdadero de una condición. Esto significa que si una condición es verdadera, entonces "not" la hará falsa, y viceversa.
#
# Estos operadores se pueden utilizar en combinación con otras sentencias condicionales y bucles para crear programas más complejos y dinámicos. Cuando entiendes cómo se utilizan los operadores lógicos, puedes crear un código más eficiente y efectivo que pueda manejar una amplia gama de situaciones.
#
#
# Ejemplos:
#
# * and:
#
# Ambas condiciones deben ser verdaderas:
#
# 	5 > 2 and 3 < 5	True
# * or:
#
# Al menos una condición debe ser verdadera:
#
#   5 > 2 or 3 > 5	True
#
# * not:
#
# Revierte el valor verdadero de una condición:
#
# 	not (5 > 2)	False

# %% [markdown]
# #Funciones de predicado (islower(), isdigit() e isalpha()):
#
# Una función de predicado es cualquier función que devuelve True o False. Por ejemplo, estos son algunos métodos de cadena que comprueban si los caracteres de una cadena cumplen ciertas condiciones:
#
# * islower() devuelve True si todos los caracteres alfabéticos de la cadena están en minúsculas;
# * isdigit() devuelve True si una cadena contiene solo números;
# * isalpha() devuelve True si una cadena contiene solo letras. Si una cadena contiene signos de puntuación o espacios, devolverá False.

# %% [markdown]
# #Sentencias if y else:
#
# En resumen, existen dos tipos principales de expresiones lógicas:
#
# * Expresiones que contienen operadores de comparación: ==, !=, >, <, >=, <=
# * Expresiones que contienen operadores lógicos: and, or, not
# * demás de esto, también hemos aprendido sobre las funciones de predicado que se pueden aplicar a las cadenas. Estas son islower(), isdigit() y isalpha().
#
# Ahora que puedes reconocer e identificar expresiones lógicas que devuelven True o False, es hora de aprender sobre los operadores condicionales.
#
# Al final de esta lección podrás utilizar las sentencias if y else para crear ramas en tu código.
#
# Una sentencia if es un operador condicional que permite ejecutar un bloque de código solo si cierta condición es verdadera; si la condición es falsa, se omitirá el bloque de código.
#
# Una sentencia condicional en Python contiene un encabezado y un cuerpo:
#
# * El encabezado contiene la condición (una expresión lógica);
# * El cuerpo contiene instrucciones (ramas de código) con una indentación de cuatro espacios.
# * Si la expresión lógica devuelve True, la sentencia if ejecutará el código en el cuerpo de la condición.
#
# Sin embargo, a veces puede ser necesario especificar la acción alternativa si la condición devuelve False. Por ejemplo: SI NO está lloviendo, ENTONCES lleva un sombrero (IF it is NOT raining, THEN take a hat).
#
# En Python, después de una sentencia if, se puede utilizar una sentencia else para ejecutar código cuando no se cumple la condición de la sentencia if.
#
# La sentencia else debe tener una indentación de cuatro espacios que la separe del bloque de código anterior. Esta es una característica útil de Python que permite un flujo de control más complejo en los programas. Además, es importante señalar que la sentencia else es opcional y se puede omitir si no se necesita.

# %%
movie_rating = 8.73 # Puntuación de The Godfather
if movie_rating >= 8.5:
    print("High rating")
else:
    print("Average rating")
# Out:
# High rating

# %% [markdown]
# #Comprobación de subcadena:
# En Python, puedes utilizar el operador in para determinar si existe una subcadena dentro de una cadena más grande. Esta es una herramienta increíblemente útil que se puede utilizar en múltiples contextos. Por ejemplo, puedes utilizar este operador para comprobar si una determinada palabra aparece en una oración o para identificar si una secuencia de caracteres específica está presente en un archivo de texto.
#
# Para utilizar este operador, simplemente escribe la subcadena que estás buscando, seguida del operador in, seguido de la cadena más grande dentro de la cual deseas buscar. Si la subcadena está presente dentro de la cadena más grande, el operador devolverá True; de lo contrario, devolverá False.

# %%
if "estoy" in "el equipo":
    print("Aquí estoy yo en el equipo")

else:
    print("Es verdad, no hay yo en el equipo.")
# Out:
# Es verdad, no hay yo en el equipo.

# %% [markdown]
# #Creación de múltiples ramas con else y elif:
# ##Condiciones múltiples:
# Las sentencias condicionales múltiples son muy comunes en Python. La sentencia elif es una abreviatura de "else if" y permite comprobar condiciones adicionales después de una sentencia if inicial.
#
# Al final de esta lección podrás utilizar la función elif en tu código para crear cualquier número de ramas.
#
# Perfeccionemos nuestro algoritmo para lidiar con el clima y agreguemos algunas opciones más:
#
# - Si llueve, lleva un paraguas.
# - Si hay sol, lleva gafas de sol.
# - Si nieva, ponte un gorro y una bufanda.
# - En caso contrario, no lleves nada.
#
#
# En el caso de un algoritmo tan complejo, la estructura simple else-if no será suficiente
#
# La variable weather del código anterior almacena el clima actual, mientras que item_to_take almacena el objeto que debemos ponernos o llevar con nosotros.
#
# El programa no funciona como debería: nos dice que no llevemos nada cuando el valor es 'lluvia' o 'sol'. ¿Por qué pasa esto? Veamos cómo funciona el código anterior si el valor de weather es 'lluvia':
#
# - if weather == 'lluvia': establece item_to_take como 'paraguas' y esto es exactamente lo que queremos.
# - if weather == 'sol': no hace nada, ya que esta condición devuelve False.
# - if weather == 'nieve': devuelve False y, luego, dentro de la sentencia else, 'nada' se establece como valor de item_to_take.
#
#
# Podemos resolver este problema fácilmente utilizando la palabra clave elif. Nos permite unir varias condiciones en una sola estructura: if-elif-else.

# %%
weather = 'lluvia'

if weather == 'lluvia':
    item_to_take = 'paraguas'
elif weather == 'sol':
    item_to_take = 'sombrero'
elif weather == 'nieve':
    item_to_take = 'gorro y bufanda'
else:
    item_to_take = 'nada'

print(weather)
print(item_to_take)
# Out:
# lluvia
# paraguas

# %% [markdown]
# #Condiciones con el bucle for:
#
# En combinación con un bucle for, las sentencias condicionales se convierten en una herramienta indispensable para los especialistas y las especialistas en datos; con ellas puedes comprobar cada elemento de la lista para una condición.
#
# Echa un vistazo a la lista years, que almacena los años de estreno de películas. Mostraremos la década correspondiente a cada año. Para hacerlo, revisaremos varios rangos que cubren los años desde 1960 hasta 2009:

# %%
years = [1994, 1972, 2008, 1993, 2003, 1994, 1966, 1999, 1962, 1997]

for year in years:
    if 1960 <= year <= 1969:
        print('La película se estrenó en la década de 1960.')
    elif 1970 <= year <= 1979:
        print('La película se estrenó en la década de 1970.')
    elif 1980 <= year <= 1989:
        print('La película se estrenó en la década de 1980.')
    elif 1990 <= year <= 1999:
        print('La película se estrenó en la década de 1990.')
    elif 2000 <= year <= 2009:
        print('La película se estrenó en la década de los 2000.')
    else:
        print('Tiempo no definido.')
# Out:
# La película se estrenó en la década de 1990.
# La película se estrenó en la década de 1970.
# La película se estrenó en la década de los 2000.
# La película se estrenó en la década de 1990.
# La película se estrenó en la década de los 2000.
# La película se estrenó en la década de 1990.
# La película se estrenó en la década de 1960.
# La película se estrenó en la década de 1990.
# La película se estrenó en la década de 1960.
# La película se estrenó en la década de 1990.

# %% [markdown]
# #Modificación de tablas:
# Las tablas son una parte integral del procesamiento y análisis de datos. En Python, las tablas suelen implementarse como listas de listas o utilizando librerías como pandas, las cuales veremos en el futuro.
#
# La modificación de tablas puede ser un paso crucial en el preprocesamiento de datos y los bucles son una forma eficaz de hacerlo. En esta lección aprenderemos cómo modificar tablas mediante bucles en Python.
#
# ##Modificación de valores en una tabla:
# La modificación de valores en una tabla es una operación común en el procesamiento de datos. Podemos utilizar bucles para modificar valores en una tabla.

# %%
movies = [
    ["The Shawshank Redemption", 1994, "Frank Darabont"],
    ["The Godfather", 1972, "Francis Ford Coppola"],
    ["The Dark Knight", 2008, "Christopher Nolan"],
    ["12 Angry Men", 1957, "Sidney Lumet"],
    ["Schindler's List", 1994, "Steven Spielberg"],
    ["The Lord of the Rings: The Return of the King", 2003, "Peter Jackson"]
]

movie_name = "Schindler's List"
correct_year = 1993

for movie in movies: # haz un bucle por todas las películas
    if movie[0] == movie_name: # si el título de la película es el que queremos arreglar
        movie[1] = correct_year # asigna el valor deseado


for movie in movies: # haz un bucle por todas las películas
    print(movie)
# Out:
# ['The Shawshank Redemption', 1994, 'Frank Darabont']
# ['The Godfather', 1972, 'Francis Ford Coppola']
# ['The Dark Knight', 2008, 'Christopher Nolan']
# ['12 Angry Men', 1957, 'Sidney Lumet']
# ["Schindler's List", 1993, 'Steven Spielberg']
# ['The Lord of the Rings: The Return of the King', 2003, 'Peter Jackson']

# %% [markdown]
# #Filtrar tablas:
# Un filtro es una herramienta útil que podemos utilizar para procesar tablas, seleccionando solo los datos que cumplan con una serie de condiciones y utilizando estas condiciones para crear nuevas tablas.
#
# Al final de esta lección, podrás explicar cómo funcionan los filtros y utilizarlos para recuperar tablas más pequeñas que contengan solamente los datos relevantes, facilitando de este modo el análisis y la manipulación de tus datos.
#
# ##Partes de un filtro:
# Un filtro para una tabla consta de tres partes:
#
# - Una variable con una lista vacía para agregar filas coincidentes.
# - Un bucle que recorre la tabla original.
# - Una sentencia condicional con if. Si una sublista cumple la condición, se agregará a la variable que almacena elementos que cumplen con nuestro filtro.

# %%
movies_info = [
    ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111],
    ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.730],
    ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499],
    ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818],
    ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625],
    ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619],
    ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521],
    ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644],
    ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106],
    ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
]

movies_filtered = [] # lista vacía para almacenar el resultado

for movie in movies_info: # recorre en bucle las filas de la tabla original
    if movie[1] == 'Japan': # si la película es de Japón,
        movies_filtered.append(movie) # agrega esta fila a movies_filtered

for movie in movies_filtered: # muestra el contenido de movies_filtered
    print(movie)
# Out:
# ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106]

# %% [markdown]
# #Operadores lógicos y filtros:
# Para crear un algoritmo de filtrado más sofisticado, puedes utilizar múltiples condiciones unidas por operadores lógicos. Al hacerlo, puedes filtrar datos en función de más de un criterio.

# %%
movies_info = [
    ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111],
    ['The Godfather', 'USA', 1972, 'drama, crime', 175, 8.730],
    ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499],
    ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818],
    ['The Lord of the Rings: The Return of the King', 'New Zealand', 2003, 'fantasy, adventure, drama', 201, 8.625],
    ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619],
    ['The Good, the Bad and the Ugly', 'Italy', 1966, 'western', 178, 8.521],
    ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644],
    ['Harakiri', 'Japan', 1962, 'drama, action, history', 133, 8.106],
    ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
]

movies_filtered = []

for movie in movies_info: # un bucle sobre cada película
    if movie[2] > 1990 and movie[1] == 'USA': # si la película se estrenó después de 1990 y en los EE. UU.,
        movies_filtered.append(movie) # la agregamos a la nueva lista

for movie in movies_filtered:
    print(movie)
# Out:
# ['The Shawshank Redemption', 'USA', 1994, 'drama', 142, 9.111]
# ['The Dark Knight', 'USA', 2008, 'fantasy, action, thriller', 152, 8.499]
# ["Schindler's List", 'USA', 1993, 'drama', 195, 8.818]
# ['Pulp Fiction', 'USA', 1994, 'thriller, comedy, crime', 154, 8.619]
# ['Fight Club', 'USA', 1999, 'thriller, drama, crime', 139, 8.644]
# ['Good Will Hunting', 'USA', 1997, 'drama, romance', 126, 8.077]
